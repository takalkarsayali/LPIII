# %% [markdown]
# # <center> Assignment - 3 </center>
#
# ##### Given a bank customer, build a neural network-based classifier that can determine whether they will leave or not in the next 6 months.
# ##### Dataset Description: The case study is from an open-source dataset from Kaggle. The dataset contains 10,000 sample points with 14 distinct features such as CustomerId, CreditScore, Geography, Gender, Age, Tenure, Balance, etc.
# ##### Perform following steps:
# ##### 1. Read the dataset.
# ##### 2. Distinguish the feature and target set and divide the data set into training and test sets.
# ##### 3. Normalize the train and test data.
# ##### 4. Initialize and build the model. Identify the points of improvement and implement the same.
# ##### 5. Print the accuracy score and confusion matrix.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import io
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
df = pd.read_csv('/Users/devarshimahajan/Desktop/practical/Churn_Modelling.csv')
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df=df.drop(['RowNumber','CustomerId','Surname'],axis=1)
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df.isna().any()
df.isna().sum()
# Out:
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
print(df.shape)
df.info()
# Out:
# (10000, 11)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CreditScore      10000 non-null  int64
#  1   Geography        10000 non-null  object
#  2   Gender           10000 non-null  object
#  3   Age              10000 non-null  int64
#  4   Tenure           10000 non-null  int64
#  5   Balance          10000 non-null  float64
#  6   NumOfProducts    10000 non-null  int64
#  7   HasCrCard        10000 non-null  int64
#  8   IsActiveMember   10000 non-null  int64
#  9   EstimatedSalary  10000 non-null  float64
#  10  Exited           10000 non-null  int64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 859.5+ KB

# %%
df.describe()
# Out:
#         CreditScore           Age        Tenure        Balance  NumOfProducts  \
# count  10000.000000  10000.000000  10000.000000   10000.000000   10000.000000
# mean     650.528800     38.921800      5.012800   76485.889288       1.530200
# std       96.653299     10.487806      2.892174   62397.405202       0.581654
# min      350.000000     18.000000      0.000000       0.000000       1.000000
# 25%      584.000000     32.000000      3.000000       0.000000       1.000000
# 50%      652.000000     37.000000      5.000000   97198.540000       1.000000
# 75%      718.000000     44.000000      7.000000  127644.240000       2.000000
# max      850.000000     92.000000     10.000000  250898.090000       4.000000
#
#          HasCrCard  IsActiveMember  EstimatedSalary        Exited
# count  10000.00000    10000.000000     10000.000000  10000.000000
# mean       0.70550        0.515100    100090.239881      0.203700
# std        0.45584        0.499797     57510.492818      0.402769
# min        0.00000        0.000000        11.580000      0.000000
# 25%        0.00000        0.000000     51002.110000      0.000000
# 50%        1.00000        1.000000    100193.915000      0.000000
# 75%        1.00000        1.000000    149388.247500      0.000000
# max        1.00000        1.000000    199992.480000      1.000000

# %%
## Scale the data
scaler=StandardScaler()
## Extract only the Numerical Columns to perform Bivariate Analysis
subset=df.drop(['Geography','Gender','HasCrCard','IsActiveMember'],axis=1)
scaled=scaler.fit_transform(subset)
scaled_df=pd.DataFrame(scaled,columns=subset.columns)
sns.pairplot(scaled_df,diag_kind='kde')

# %%
sns.heatmap(scaled_df.corr(),annot=True,cmap='rainbow')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### From the above plots, We can see that there is no significant Linear relationship between the features

# %%
## Categorical Features vs Target Variable
plt.rcParams['figure.figsize'] = [3, 3]

sns.countplot(x='Geography',data=df,hue='Exited')
plt.show()
sns.countplot(x='Gender',data=df,hue='Exited')
plt.show()
sns.countplot(x='HasCrCard',data=df,hue='Exited')
plt.show()
sns.countplot(x='IsActiveMember',data=df,hue='Exited')
plt.show()

# %% [markdown]
# ##### Analysing the Numerical Features relationship with the Target variable. Here 'Exited' is the Target Feature.

# %%
subset=subset.drop('Exited',axis=1)
for i in subset.columns:  
    sns.boxplot(df['Exited'],df[i],hue=df['Gender'])
    plt.rcParams['figure.figsize'] = [3, 3]
    plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Insights from Bivariate Plots
#
#
# 1. The Avg Credit Score seem to be almost the same for Active and Churned customers
# 2. Young People seem to stick to the bank compared to older people
# 3. The Average Bank Balance is high for Churned Customers
# 4. The churning rate is high with German Customers
# 5. The Churning rate is high among the Non-Active Members

# %% [markdown]
# ### 4. Distinguish the Target and Feature Set and divide the dataset into Training and Test sets

# %%
X=df.drop('Exited',axis=1)
y=df.pop('Exited')

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.10,random_state=5)
X_train,X_val,y_train,y_val=train_test_split(X_train,y_train,test_size=0.10,random_state=5)
print("X_train size is {}".format(X_train.shape[0]))
print("X_val size is {}".format(X_val.shape[0]))
print("X_test size is {}".format(X_test.shape[0]))
# Out:
# X_train size is 8100
# X_val size is 900
# X_test size is 1000

# %%
## Standardising the train, Val and Test data
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
num_cols=['CreditScore','Age','Tenure','Balance','NumOfProducts','EstimatedSalary']
num_subset=scaler.fit_transform(X_train[num_cols])
X_train_num_df=pd.DataFrame(num_subset,columns=num_cols)
X_train_num_df['Geography']=list(X_train['Geography'])
X_train_num_df['Gender']=list(X_train['Gender'])
X_train_num_df['HasCrCard']=list(X_train['HasCrCard'])
X_train_num_df['IsActiveMember']=list(X_train['IsActiveMember'])
X_train_num_df.head()
## Standardise the Validation data
num_subset=scaler.fit_transform(X_val[num_cols])
X_val_num_df=pd.DataFrame(num_subset,columns=num_cols)
X_val_num_df['Geography']=list(X_val['Geography'])
X_val_num_df['Gender']=list(X_val['Gender'])
X_val_num_df['HasCrCard']=list(X_val['HasCrCard'])
X_val_num_df['IsActiveMember']=list(X_val['IsActiveMember'])
## Standardise the Test data
num_subset=scaler.fit_transform(X_test[num_cols])
X_test_num_df=pd.DataFrame(num_subset,columns=num_cols)
X_test_num_df['Geography']=list(X_test['Geography'])
X_test_num_df['Gender']=list(X_test['Gender'])
X_test_num_df['HasCrCard']=list(X_test['HasCrCard'])
X_test_num_df['IsActiveMember']=list(X_test['IsActiveMember'])

# %%
## Convert the categorical features to numerical
X_train_num_df=pd.get_dummies(X_train_num_df,columns=['Geography','Gender'])
X_test_num_df=pd.get_dummies(X_test_num_df,columns=['Geography','Gender'])
X_val_num_df=pd.get_dummies(X_val_num_df,columns=['Geography','Gender'])
X_train_num_df.head()
# Out:
#    CreditScore       Age    Tenure   Balance  NumOfProducts  EstimatedSalary  \
# 0    -1.178587 -1.041960 -1.732257  0.198686       0.820905         1.560315
# 1    -0.380169 -1.326982  1.730718 -0.022020      -0.907991        -0.713592
# 2    -0.349062  1.808258 -0.693364  0.681178       0.820905        -1.126515
# 3     0.625629  2.378302 -0.347067 -1.229191       0.820905        -1.682740
# 4    -0.203895 -1.136967  1.730718  0.924256      -0.907991         1.332535
#
#    HasCrCard  IsActiveMember  Geography_France  Geography_Germany  \
# 0          1               1                 1                  0
# 1          1               0                 0                  0
# 2          1               0                 0                  1
# 3          1               1                 1                  0
# 4          1               1                 0                  0
#
#    Geography_Spain  Gender_Female  Gender_Male
# 0                0              0            1
# 1                1              1            0
# 2                0              1            0
# 3                0              0            1
# 4                1              0            1

# %% [markdown]
# ### Initialise and build the Model

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

model=Sequential()
model.add(Dense(7,activation='relu'))
model.add(Dense(10,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
import tensorflow as tf
optimizer=tf.keras.optimizers.Adam(0.01)
model.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])

# %%
model.fit(X_train_num_df,y_train,epochs=100,batch_size=10,verbose=1)
# Out:
# Epoch 1/100
# 2023-09-14 12:41:50.366457: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 810/810 [==============================] - 1s 495us/step - loss: 0.3918 - accuracy: 0.8309
# Epoch 2/100
# 810/810 [==============================] - 0s 455us/step - loss: 0.3522 - accuracy: 0.8563
# Epoch 3/100
# 810/810 [==============================] - 0s 451us/step - loss: 0.3445 - accuracy: 0.8600
# Epoch 4/100
# 810/810 [==============================] - 0s 452us/step - loss: 0.3435 - accuracy: 0.8589
# Epoch 5/100
# 810/810 [==============================] - 0s 450us/step - loss: 0.3450 - accuracy: 0.8573
# Epoch 6/100
# 810/810 [==============================] - 0s 453us/step - loss: 0.3403 - accuracy: 0.8614
# Epoch 7/100
# 810/810 [==============================] - 0s 451us/step - loss: 0.3390 - accuracy: 0.8638
# Epoch 8/100
# 810/810 [==============================] - 0s 450us/step - loss: 0.3394 - accuracy: 0.8616
# Epoch 9/100
# 810/810 [==============================] - 0s 451us/step - loss: 0.3392 - accuracy: 0.8647
# Epoch 10/100
# 810/810 [==============================] - 0s 451us/step - loss: 0.3372 - accuracy: 0.8625
# Epoch 11/100
# 810/810 [==============================] - 0s 451us/step - loss: 0.3380 - accuracy: 0.8606
# Epoch 12/100
# 810/810 [==============================] - 0s 452us/step - loss: 0.3371 - accuracy: 0.8617
# Epoch 13/100
# 810/810 [==============================] - 0s 452us/step - loss: 0.3361 - accuracy: 0.8633
# Epoch 14/100
# 810/810 [==============================] - 0s 453us/step - loss: 0.3354 - accuracy: 0.8625
# Epoch 15/100
# 810/810 [==============================] - 0s 457us/step - loss: 0.3350 - accuracy: 0.8643
# Epoch 16/100
# 810/810 [==============================] - 0s 452us/step - loss: 0.3350 - accuracy: 0.8663
# Epoch 17/100
# 810/810 [==============================] - 0s 452us/step - loss: 0.3342 - accuracy: 0.8647
# Epoch 18/100
# 810/810 [==============================] - 0s 452us/step - loss: 0.3348 - accuracy: 0.8633
# Epoch 19/100
# 810/810 [==============================] - 0s 453us/step - loss: 0.3341 - accuracy: 0.8642
# Epoch 20/100
# 810/810 [==============================] - 0s 452us/step - loss: 0.3365 - accuracy: 0.8637
# Epoch 21/100
# 810/810 [==============================] - 0s 455us/step - loss: 0.3339 - accuracy: 0.8642
# Epoch 22/100
# 810/810 [==============================] - 0s 458us/step - loss: 0.3333 - accuracy: 0.8632
# Epoch 23/100
# 810/810 [==============================] - 0s 499us/step - loss: 0.3348 - accuracy: 0.8647
# Epoch 24/100
# 810/810 [==============================] - 0s 453us/step - loss: 0.3349 - accuracy: 0.8677
# Epoch 25/100
# 810/810 [==============================] - 0s 453us/step - loss: 0.3333 - accuracy: 0.8664
# Epoch 26/100
# 810/810 [==============================] - 0s 453us/step - loss: 0.3330 - accuracy: 0.8641
# Epoch 27/100
# 810/810 [==============================] - 0s 453us/step - loss: 0.3320 - accuracy: 0.8644
# Epoch 28/100
# 810/810 [==============================] - 0s 452us/step - loss: 0.3327 - accuracy: 0.8647
# Epoch 29/100
# 810/810 [==============================] - 0s 456us/step - loss: 0.3337 - accuracy: 0.8668
# Epoch 30/100
# 810/810 [==============================] - 0s 454us/step - loss: 0.3316 - accuracy: 0.8641
# Epoch 31/100
# 810/810 [==============================] - 0s 451us/step - loss: 0.3322 - accuracy: 0.8663
# Epoch 32/100
# 810/810 [==============================] - 0s 452us/step - loss: 0.3318 - accuracy: 0.8653
# Epoch 33/100
# 810/810 [==============================] - 0s 453us/step - loss: 0.3322 - accuracy: 0.8652
# Epoch 34/100
# 810/810 [==============================] - 0s 452us/step - loss: 0.3314 - accuracy: 0.8653
# Epoch 35/100
# 810/810 [==============================] - 0s 452us/step - loss: 0.3319 - accuracy: 0.8636
# Epoch 36/100
# 810/810 [==============================] - 0s 476us/step - loss: 0.3301 - accuracy: 0.8625
# Epoch 37/100
# 810/810 [==============================] - 0s 453us/step - loss: 0.3305 - accuracy: 0.8653
# Epoch 38/100
# 810/810 [==============================] - 0s 451us/step - loss: 0.3312 - accuracy: 0.8643
# Epoch 39/100
# 810/810 [==============================] - 0s 458us/step - loss: 0.3302 - accuracy: 0.8653
# Epoch 40/100
# 810/810 [==============================] - 0s 450us/step - loss: 0.3288 - accuracy: 0.8665
# Epoch 41/100
# 810/810 [==============================] - 0s 453us/step - loss: 0.3292 - accuracy: 0.8651
# Epoch 42/100
# 810/810 [==============================] - 0s 453us/step - loss: 0.3298 - accuracy: 0.8654
# Epoch 43/100
# 810/810 [==============================] - 0s 455us/step - loss: 0.3289 - accuracy: 0.8659
# Epoch 44/100
# 810/810 [==============================] - 0s 454us/step - loss: 0.3285 - accuracy: 0.8675
# Epoch 45/100
# 810/810 [==============================] - 0s 454us/step - loss: 0.3307 - accuracy: 0.8658
# Epoch 46/100
# 810/810 [==============================] - 0s 499us/step - loss: 0.3285 - accuracy: 0.8658
# Epoch 47/100
# 810/810 [==============================] - 0s 492us/step - loss: 0.3283 - accuracy: 0.8658
# Epoch 48/100
# 810/810 [==============================] - 0s 455us/step - loss: 0.3276 - accuracy: 0.8663
# Epoch 49/100
# 810/810 [==============================] - 0s 455us/step - loss: 0.3289 - accuracy: 0.8662
# Epoch 50/100
# 810/810 [==============================] - 0s 456us/step - loss: 0.3283 - accuracy: 0.8658
# Epoch 51/100
# 810/810 [==============================] - 0s 460us/step - loss: 0.3284 - accuracy: 0.8658
# Epoch 52/100
# 810/810 [==============================] - 0s 457us/step - loss: 0.3298 - accuracy: 0.8652
# Epoch 53/100
# 810/810 [==============================] - 0s 456us/step - loss: 0.3287 - accuracy: 0.8644
# Epoch 54/100
# 810/810 [==============================] - 0s 456us/step - loss: 0.3290 - accuracy: 0.8660
# Epoch 55/100
# 810/810 [==============================] - 0s 456us/step - loss: 0.3296 - accuracy: 0.8657
# Epoch 56/100
# 810/810 [==============================] - 0s 456us/step - loss: 0.3278 - accuracy: 0.8654
# Epoch 57/100
# 810/810 [==============================] - 0s 479us/step - loss: 0.3286 - accuracy: 0.8659
# Epoch 58/100
# 810/810 [==============================] - 0s 455us/step - loss: 0.3277 - accuracy: 0.8664
# Epoch 59/100
# 810/810 [==============================] - 0s 454us/step - loss: 0.3277 - accuracy: 0.8668
# Epoch 60/100
# 810/810 [==============================] - 0s 490us/step - loss: 0.3272 - accuracy: 0.8681
# Epoch 61/100
# 810/810 [==============================] - 0s 457us/step - loss: 0.3276 - accuracy: 0.8656
# Epoch 62/100
# 810/810 [==============================] - 0s 455us/step - loss: 0.3288 - accuracy: 0.8688
# Epoch 63/100
# 810/810 [==============================] - 0s 459us/step - loss: 0.3290 - accuracy: 0.8681
# Epoch 64/100
# 810/810 [==============================] - 0s 456us/step - loss: 0.3287 - accuracy: 0.8691
# Epoch 65/100
# 810/810 [==============================] - 0s 456us/step - loss: 0.3264 - accuracy: 0.8678
# Epoch 66/100
# 810/810 [==============================] - 0s 455us/step - loss: 0.3290 - accuracy: 0.8663
# Epoch 67/100
# 810/810 [==============================] - 0s 483us/step - loss: 0.3276 - accuracy: 0.8657
# Epoch 68/100
# 810/810 [==============================] - 0s 456us/step - loss: 0.3262 - accuracy: 0.8680
# Epoch 69/100
# 810/810 [==============================] - 0s 458us/step - loss: 0.3283 - accuracy: 0.8663
# Epoch 70/100
# 810/810 [==============================] - 0s 456us/step - loss: 0.3265 - accuracy: 0.8688
# Epoch 71/100
# 810/810 [==============================] - 0s 456us/step - loss: 0.3254 - accuracy: 0.8698
# Epoch 72/100
# 810/810 [==============================] - 0s 457us/step - loss: 0.3282 - accuracy: 0.8678
# Epoch 73/100
# 810/810 [==============================] - 0s 456us/step - loss: 0.3270 - accuracy: 0.8648
# Epoch 74/100
# 810/810 [==============================] - 0s 481us/step - loss: 0.3269 - accuracy: 0.8678
# Epoch 75/100
# 810/810 [==============================] - 0s 457us/step - loss: 0.3273 - accuracy: 0.8664
# Epoch 76/100
# 810/810 [==============================] - 0s 456us/step - loss: 0.3262 - accuracy: 0.8674
# Epoch 77/100
# 810/810 [==============================] - 0s 457us/step - loss: 0.3290 - accuracy: 0.8669
# Epoch 78/100
# 810/810 [==============================] - 0s 461us/step - loss: 0.3270 - accuracy: 0.8663
# Epoch 79/100
# 810/810 [==============================] - 0s 454us/step - loss: 0.3253 - accuracy: 0.8679
# Epoch 80/100
# 810/810 [==============================] - 0s 453us/step - loss: 0.3257 - accuracy: 0.8679
# Epoch 81/100
# 810/810 [==============================] - 0s 449us/step - loss: 0.3279 - accuracy: 0.8667
# Epoch 82/100
# 810/810 [==============================] - 0s 445us/step - loss: 0.3282 - accuracy: 0.8642
# Epoch 83/100
# 810/810 [==============================] - 0s 449us/step - loss: 0.3272 - accuracy: 0.8660
# Epoch 84/100
# 810/810 [==============================] - 0s 453us/step - loss: 0.3271 - accuracy: 0.8659
# Epoch 85/100
# 810/810 [==============================] - 0s 447us/step - loss: 0.3275 - accuracy: 0.8657
# Epoch 86/100
# 810/810 [==============================] - 0s 449us/step - loss: 0.3252 - accuracy: 0.8684
# Epoch 87/100
# 810/810 [==============================] - 0s 449us/step - loss: 0.3255 - accuracy: 0.8656
# Epoch 88/100
# 810/810 [==============================] - 0s 489us/step - loss: 0.3263 - accuracy: 0.8660
# Epoch 89/100
# 810/810 [==============================] - 0s 459us/step - loss: 0.3261 - accuracy: 0.8679
# Epoch 90/100
# 810/810 [==============================] - 0s 450us/step - loss: 0.3255 - accuracy: 0.8669
# Epoch 91/100
# 810/810 [==============================] - 0s 447us/step - loss: 0.3266 - accuracy: 0.8668
# Epoch 92/100
# 810/810 [==============================] - 0s 448us/step - loss: 0.3270 - accuracy: 0.8663
# Epoch 93/100
# 810/810 [==============================] - 0s 451us/step - loss: 0.3267 - accuracy: 0.8673
# Epoch 94/100
# 810/810 [==============================] - 0s 448us/step - loss: 0.3266 - accuracy: 0.8683
# Epoch 95/100
# 810/810 [==============================] - 0s 450us/step - loss: 0.3255 - accuracy: 0.8678
# Epoch 96/100
# 810/810 [==============================] - 0s 451us/step - loss: 0.3267 - accuracy: 0.8663
# Epoch 97/100
# 810/810 [==============================] - 0s 450us/step - loss: 0.3254 - accuracy: 0.8684
# Epoch 98/100
# 810/810 [==============================] - 0s 449us/step - loss: 0.3255 - accuracy: 0.8675
# Epoch 99/100
# 810/810 [==============================] - 0s 448us/step - loss: 0.3253 - accuracy: 0.8675
# Epoch 100/100
# 810/810 [==============================] - 0s 449us/step - loss: 0.3258 - accuracy: 0.8695

# %%
y_pred_val=model.predict(X_val_num_df)
y_pred_val[y_pred_val>0.5]=1
y_pred_val[y_pred_val <0.5]=0
# Out:
# 29/29 [==============================] - 0s 393us/step

# %%
y_pred_val=y_pred_val.tolist()
X_compare_val=X_val.copy()
X_compare_val['y_actual']=y_val
X_compare_val['y_pred']=y_pred_val
X_compare_val.head(10)
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 340           642   Germany  Female   40       6  129502.49              2
# 8622          706   Germany    Male   36       9   58571.18              2
# 8401          535     Spain    Male   58       1       0.00              2
# 4338          714     Spain    Male   25       2       0.00              1
# 8915          606    France    Male   36       1  155655.46              1
# 2624          605     Spain  Female   29       3  116805.82              1
# 2234          720    France  Female   38      10       0.00              2
# 349           582    France    Male   39       5       0.00              2
# 3719          850    France  Female   62       1  124678.35              1
# 2171          526   Germany    Male   58       9  190298.89              2
#
#       HasCrCard  IsActiveMember  EstimatedSalary  y_actual y_pred
# 340           0               1         86099.23         1  [0.0]
# 8622          1               0         40774.01         0  [0.0]
# 8401          1               1         11779.98         1  [0.0]
# 4338          1               1        132979.43         0  [0.0]
# 8915          1               1        192387.51         1  [0.0]
# 2624          0               0          4092.75         0  [0.0]
# 2234          1               1         56229.72         1  [0.0]
# 349           1               1        129892.93         0  [0.0]
# 3719          1               0         70916.00         1  [1.0]
# 2171          1               1        191263.76         0  [0.0]

# %%
from sklearn.metrics import confusion_matrix
cm_val=confusion_matrix(y_val,y_pred_val)
disp1 = ConfusionMatrixDisplay(confusion_matrix=cm_val)
disp1.plot()
plt.show()

# %%
loss1,accuracy1=model.evaluate(X_train_num_df,y_train,verbose=False)
loss2,accuracy2=model.evaluate(X_val_num_df,y_val,verbose=False)
print("Train Loss {}".format(loss1))
print("Train Accuracy {}".format(accuracy1))
print("Val Loss {}".format(loss2))
print("Val Accuracy {}".format(accuracy2))
# Out:
# Train Loss 0.32059919834136963
# Train Accuracy 0.8696296215057373
# Val Loss 0.34725087881088257
# Val Accuracy 0.855555534362793

# %%
from sklearn import metrics
y_pred_test=model.predict(X_test_num_df)
y_pred_test[y_pred_test>0.5]=1
y_pred_test[y_pred_test <0.5]=0
cm_test=metrics.confusion_matrix(y_test,y_pred_test)
disp2 = ConfusionMatrixDisplay(confusion_matrix=cm_test)
disp2.plot()
plt.show()
# Out:
# 32/32 [==============================] - 0s 406us/step

# %%
loss3,accuracy3=model.evaluate(X_test_num_df,y_test,verbose=False)
print("Test Accuracy is {}".format(accuracy3))
print("Test loss is {}".format(loss3))
# Out:
# Test Accuracy is 0.8399999737739563
# Test loss is 0.3659769892692566
